# %%
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# load data
data_folder = Path('data') / 'yoon_results'
f_name = 'curvatures_ryan_natural_periphery_06_DAM.csv'

data = np.loadtxt(Path(data_folder) / f_name, delimiter=',')

# %%
plt.boxplot(data, tick_labels=['Synthetic data (null model)', 'Real data (human subject)'])
plt.ylabel('Estimated curvature (°)')
plt.show()
